# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json

# %%
tmdb_2000 = pd.read_csv(r'C:\Users\dhowa\anaconda3\etc\profile.d\0130-Wk-13-local-workflow-practice\Project-3-Part-2\Data\final_tmdb_data2000.csv.gz')
tmdb_2000.info()
tmdb_2000.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1233 entries, 0 to 1232
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1233 non-null   object
#  1   adult                  1232 non-null   float64
#  2   backdrop_path          678 non-null    object
#  3   belongs_to_collection  113 non-null    object
#  4   budget                 1232 non-null   float64
#  5   genres                 1232 non-null   object
#  6   homepage               63 non-null     object
#  7   id                     1232 non-null   float64
#  8   original_language      1232 non-null   object
#  9   original_title         1232 non-null   object
#  10  overview               1211 non-null   object
#  11  popularity             1232 non-null   float64
#  12  poster_path            1110 non-null   object
#  13  production_companies   1232 non-null   object
# ...

# %%
tmdb_2001 = pd.read_csv(r'C:\Users\dhowa\anaconda3\etc\profile.d\0130-Wk-13-local-workflow-practice\Project-3-Part-2\Data\final_tmdb_data2001.csv.gz')
tmdb_2001.info()
tmdb_2001.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1326 entries, 0 to 1325
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1326 non-null   object
#  1   adult                  1325 non-null   float64
#  2   backdrop_path          712 non-null    object
#  3   belongs_to_collection  92 non-null     object
#  4   budget                 1325 non-null   float64
#  5   genres                 1325 non-null   object
#  6   homepage               108 non-null    object
#  7   id                     1325 non-null   float64
#  8   original_language      1325 non-null   object
#  9   original_title         1325 non-null   object
#  10  overview               1296 non-null   object
#  11  popularity             1325 non-null   float64
#  12  poster_path            1191 non-null   object
#  13  production_companies   1325 non-null   object
# ...

# %%
tmdb_combined_df = pd.concat((tmdb_2000, tmdb_2000), ignore_index=True)
tmdb_combined_df.info()
tmdb_combined_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2466 entries, 0 to 2465
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2466 non-null   object
#  1   adult                  2464 non-null   float64
#  2   backdrop_path          1356 non-null   object
#  3   belongs_to_collection  226 non-null    object
#  4   budget                 2464 non-null   float64
#  5   genres                 2464 non-null   object
#  6   homepage               126 non-null    object
#  7   id                     2464 non-null   float64
#  8   original_language      2464 non-null   object
#  9   original_title         2464 non-null   object
#  10  overview               2422 non-null   object
#  11  popularity             2464 non-null   float64
#  12  poster_path            2220 non-null   object
#  13  production_companies   2464 non-null   object
# ...

# %%
tmdb_combined_df.to_csv('/Data/tmdb_results_combined.csv.gz')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 tmdb_combined_df.to_csv('/Data/tmdb_results_combined.csv.gz')
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
# ...

# %%
valid_finance_df = tmdb_combined_df[(tmdb_combined_df['budget'] > 0) | (tmdb_combined_df['revenue'] > 0)]
valid_finance_df.info()
valid_finance_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 596 entries, 1 to 2464
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                596 non-null    object
#  1   adult                  596 non-null    float64
#  2   backdrop_path          522 non-null    object
#  3   belongs_to_collection  112 non-null    object
#  4   budget                 596 non-null    float64
#  5   genres                 596 non-null    object
#  6   homepage               50 non-null     object
#  7   id                     596 non-null    float64
#  8   original_language      596 non-null    object
#  9   original_title         596 non-null    object
#  10  overview               596 non-null    object
#  11  popularity             596 non-null    float64
#  12  poster_path            586 non-null    object
#  13  production_companies   596 non-null    object
# ...

# %%
valid_finance_df['certification'].value_counts().plot(kind='bar', 
                                                      color =['blue','red',
                                                             'purple', 'cyan',
                                                             'black'])
plt.title('Movie Counts By Certifications')
plt.xlabel('Certifications')
plt.ylabel('Counts')
plt.tight_layout;

# %%
cert_counts = valid_finance_df['certification'].value_counts()
cert_counts
# Out:
# R        220
# PG-13    122
# PG        36
# NR        20
# G         16
# Name: certification, dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
avg_rev = valid_finance_df.groupby('certification')['revenue'].mean()
avg_rev
# Out:
# certification
# G       105343104.38
# NR       10169454.00
# PG       76657659.89
# PG-13   102032591.39
# R        30282598.62
# Name: revenue, dtype: float64

# %%
avg_rev.plot(kind='bar', color =['blue','orange', 'purple', 'pink','green'])
plt.title('Average Movie Revenues Per Certification')
plt.xlabel('Certifications')
plt.ylabel('Revenue in Dollars')
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout;

# %%
avg_budg = valid_finance_df.groupby('certification')['budget'].mean()
avg_budg
# Out:
# certification
# G       45000000.00
# NR       9034009.40
# PG      45550000.22
# PG-13   45668032.79
# R       18244954.55
# Name: budget, dtype: float64

# %%
avg_budg.plot(kind='bar', color =['blue','red', 'orange', 'pink','green'])
plt.title('Average Movie Budget Per Certification')
plt.xlabel('Certifications')
plt.ylabel('Budget in Dollars')
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout;
