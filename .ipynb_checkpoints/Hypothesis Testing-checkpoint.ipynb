# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Float, String, Text
import os, glob
import scipy.stats as stats

# %%
dirpath = 'Data/'
test = pd.read_csv(os.path.join(dirpath, 'final_tmdb_data2001.csv.gz'))
test.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century, they'd be p...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         6.327     1188.0         PG-13
# 2    0.0         5.000        3.0           NaN
# 3    0.0         4.536      124.0         PG-13
# 4    0.0         5.100       29.0             R
#
# [5 rows x 26 columns]

# %%
path = 'Data/final_tmdb_data*.csv.gz'
chunked_files = sorted(glob.glob(path))
chunked_files
# Out:
# ['Data\\final_tmdb_data2000.csv.gz', 'Data\\final_tmdb_data2001.csv.gz']

# %%
tmdb_df = pd.concat([pd.read_csv(file, index_col=0) for file in chunked_files])
tmdb_df.info()
tmdb_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2559 entries, 0 to tt9071078
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  2557 non-null   float64
#  1   backdrop_path          1390 non-null   object
#  2   belongs_to_collection  205 non-null    object
#  3   budget                 2557 non-null   float64
#  4   genres                 2557 non-null   object
#  5   homepage               171 non-null    object
#  6   id                     2557 non-null   float64
#  7   original_language      2557 non-null   object
#  8   original_title         2557 non-null   object
#  9   overview               2507 non-null   object
#  10  popularity             2557 non-null   float64
#  11  poster_path            2301 non-null   object
#  12  production_companies   2557 non-null   object
#  13  production_countries   2557 non-null   object
#  14  release_date           2539 non-null   object
#  15  revenue                2557 non-null   float64
#  16  runtime                2557 non-null   float64
#  17  spoken_languages       2557 non-null   object
#  18  status                 2557 non-null   object
#  19  tagline                1098 non-null   object
#  20  title                  2557 non-null   object
#  21  video                  2557 non-null   float64
#  22  vote_average           2557 non-null   float64
#  23  vote_count             2557 non-null   float64
#  24  certification          814 non-null    object
# dtypes: float64(9), object(16)
# memory usage: 519.8+ KB
#            adult                     backdrop_path belongs_to_collection  \
# imdb_id
# 0            NaN                               NaN                   NaN
# tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# tt0113092    0.0                               NaN                   NaN
# tt0116391    0.0                               NaN                   NaN
# tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#                budget                                             genres  \
# imdb_id
# 0                 NaN                                                NaN
# tt0113026  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# tt0113092         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# tt0116391         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# tt0118694    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#           homepage        id original_language   original_title  \
# imdb_id
# 0              NaN       NaN               NaN              NaN
# tt0113026      NaN   62127.0                en  The Fantasticks
# tt0113092      NaN  110977.0                en    For the Cause
# tt0116391      NaN  442869.0                hi             Gang
# tt0118694      NaN     843.0                cn             花樣年華
#
#                                                     overview  ...     revenue  \
# imdb_id                                                       ...
# 0                                                        NaN  ...         NaN
# tt0113026  Two rural teens sing and dance their way throu...  ...         0.0
# tt0113092  Earth is in a state of constant war and two co...  ...         0.0
# tt0116391  After falling prey to underworld, four friends...  ...         0.0
# tt0118694  Two neighbors become intimate after discoverin...  ...  12854953.0
#
#           runtime                                   spoken_languages  \
# imdb_id
# 0             NaN                                                NaN
# tt0113026    86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# tt0113092   100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# tt0116391   152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# tt0118694    99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#              status                                            tagline  \
# imdb_id
# 0               NaN                                                NaN
# tt0113026  Released      Try to remember the first time magic happened
# tt0113092  Released       The ultimate showdown on a forbidden planet.
# tt0116391  Released                                                NaN
# tt0118694  Released  Feel the heat, keep the feeling burning, let t...
#
#                           title  video vote_average vote_count certification
# imdb_id
# 0                           NaN    NaN          NaN        NaN           NaN
# tt0113026       The Fantasticks    0.0        5.500       22.0           NaN
# tt0113092         For the Cause    0.0        5.100        8.0           NaN
# tt0116391                  Gang    0.0        4.000        1.0           NaN
# tt0118694  In the Mood for Love    0.0        8.117     2200.0            PG
#
# [5 rows x 25 columns]

# %%
tmdb_df = tmdb_df.reset_index()
tmdb_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ...     revenue  runtime  \
# 0       NaN               NaN              NaN  ...         NaN      NaN
# 1   62127.0                en  The Fantasticks  ...         0.0     86.0
# 2  110977.0                en    For the Cause  ...         0.0    100.0
# 3  442869.0                hi             Gang  ...         0.0    152.0
# 4     843.0                cn             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         4.000        1.0           NaN
# 4    0.0         8.117     2200.0            PG
#
# [5 rows x 26 columns]

# %%
tmdb_df = tmdb_df.drop([0], axis=0)
tmdb_df = tmdb_df.reset_index(drop=True)
tmdb_df.info()
tmdb_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2558 entries, 0 to 2557
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2558 non-null   object
#  1   adult                  2557 non-null   float64
#  2   backdrop_path          1390 non-null   object
#  3   belongs_to_collection  205 non-null    object
#  4   budget                 2557 non-null   float64
#  5   genres                 2557 non-null   object
#  6   homepage               171 non-null    object
#  7   id                     2557 non-null   float64
#  8   original_language      2557 non-null   object
#  9   original_title         2557 non-null   object
#  10  overview               2507 non-null   object
#  11  popularity             2557 non-null   float64
#  12  poster_path            2301 non-null   object
#  13  production_companies   2557 non-null   object
#  14  production_countries   2557 non-null   object
#  15  release_date           2539 non-null   object
#  16  revenue                2557 non-null   float64
#  17  runtime                2557 non-null   float64
#  18  spoken_languages       2557 non-null   object
#  19  status                 2557 non-null   object
#  20  tagline                1098 non-null   object
#  21  title                  2557 non-null   object
#  22  video                  2557 non-null   float64
#  23  vote_average           2557 non-null   float64
#  24  vote_count             2557 non-null   float64
#  25  certification          814 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 519.7+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1  tt0113092    0.0                               NaN                   NaN
# 2  tt0116391    0.0                               NaN                   NaN
# 3  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4  tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 1         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 2         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 3    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
# 4         0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
#
#          id original_language   original_title  ...     revenue  runtime  \
# 0   62127.0                en  The Fantasticks  ...         0.0     86.0
# 1  110977.0                en    For the Cause  ...         0.0    100.0
# 2  442869.0                hi             Gang  ...         0.0    152.0
# 3     843.0                cn             花樣年華  ...  12854953.0     99.0
# 4   49511.0                en   Chinese Coffee  ...         0.0     99.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average vote_count certification
# 0    0.0         5.500       22.0           NaN
# 1    0.0         5.100        8.0           NaN
# 2    0.0         4.000        1.0           NaN
# 3    0.0         8.117     2200.0            PG
# 4    0.0         6.800       49.0             R
#
# [5 rows x 26 columns]

# %%
tmdb_df.columns
# Out:
# Index(['imdb_id', 'adult', 'backdrop_path', 'belongs_to_collection', 'budget',
#        'genres', 'homepage', 'id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'certification'],
#       dtype='object')

# %%
tmdb_df.duplicated().sum()
# Out:
# 0

# %%
tmdb_df = tmdb_df.drop_duplicates()
tmdb_df.duplicated().sum()
# Out:
# 0

# %%
tmdb_df = tmdb_df.loc[tmdb_df['imdb_id']!='0']
tmdb_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1     tt0113092    0.0                               NaN
# 2     tt0116391    0.0                               NaN
# 3     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 4     tt0118852    0.0  /vceiGZ3uavAEHlTA7v0GjQsGVKe.jpg
# ...         ...    ...                               ...
# 2553  tt7797670    0.0                               NaN
# 2554  tt7797790    0.0                               NaN
# 2555  tt8665056    0.0                               NaN
# 2556  tt8795764    0.0                               NaN
# 2557  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN  10000000.0
# 1                      NaN         0.0
# 2                      NaN         0.0
# 3                      NaN    150000.0
# 4                      NaN         0.0
# ...                    ...         ...
# 2553                   NaN         0.0
# 2554                   NaN         0.0
# 2555                   NaN         0.0
# 2556                   NaN         0.0
# 2557                   NaN         0.0
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1              [{'id': 878, 'name': 'Science Fiction'}]
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4                         [{'id': 18, 'name': 'Drama'}]
# ...                                                 ...
# 2553                     [{'id': 27, 'name': 'Horror'}]
# 2554                     [{'id': 27, 'name': 'Horror'}]
# 2555                    [{'id': 37, 'name': 'Western'}]
# 2556                     [{'id': 27, 'name': 'Horror'}]
# 2557                     [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 0                                                   NaN   62127.0
# 1                                                   NaN  110977.0
# 2                                                   NaN  442869.0
# 3                                                   NaN     843.0
# 4                                                   NaN   49511.0
# ...                                                 ...       ...
# 2553                                                NaN  956214.0
# 2554                                                NaN  956219.0
# 2555  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 2556  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 2557                                                NaN  201706.0
#
#      original_language                              original_title  ...  \
# 0                   en                             The Fantasticks  ...
# 1                   en                               For the Cause  ...
# 2                   hi                                        Gang  ...
# 3                   cn                                        花樣年華  ...
# 4                   en                              Chinese Coffee  ...
# ...                ...                                         ...  ...
# 2553                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 2554                en         Edmund Kemper Part 3: La mort sévit  ...
# 2555                en                        Guns Along The Bravo  ...
# 2556                en                                   New Breed  ...
# 2557                cn                                        致命密函  ...
#
#          revenue  runtime                                   spoken_languages  \
# 0            0.0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 3     12854953.0     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# 4            0.0     99.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 2553         0.0     91.0                                                 []
# 2554         0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 2555         0.0     85.0                                                 []
# 2556         0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2557         0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 0     Released      Try to remember the first time magic happened
# 1     Released       The ultimate showdown on a forbidden planet.
# 2     Released                                                NaN
# 3     Released  Feel the heat, keep the feeling burning, let t...
# 4     Released  There's a fine line between friendship and bet...
# ...        ...                                                ...
# 2553  Released                                                NaN
# 2554  Released                                                NaN
# 2555  Released  Evil came to the Southwest until three blazing...
# 2556  Released                                                NaN
# 2557  Released                                                NaN
#
#                                            title  video  vote_average  \
# 0                                The Fantasticks    0.0         5.500
# 1                                  For the Cause    0.0         5.100
# 2                                           Gang    0.0         4.000
# 3                           In the Mood for Love    0.0         8.117
# 4                                 Chinese Coffee    0.0         6.800
# ...                                          ...    ...           ...
# 2553  Edmund Kemper Part 2: La Mort C'est La Vie    0.0         0.000
# 2554         Edmund Kemper Part 3: La mort sévit    0.0         0.000
# 2555                        Guns Along The Bravo    0.0         0.000
# 2556                                   New Breed    0.0         0.000
# 2557                              Chinese Heroes    0.0         3.000
#
#      vote_count certification
# 0          22.0           NaN
# 1           8.0           NaN
# 2           1.0           NaN
# 3        2200.0            PG
# 4          49.0             R
# ...         ...           ...
# 2553        0.0           NaN
# 2554        0.0           NaN
# 2555        0.0           NaN
# 2556        0.0            NR
# 2557        2.0           NaN
#
# [2557 rows x 26 columns]

# %%
col = tmdb_df[['imdb_id','budget','revenue','certification']]

for i in col.columns:
    missing = col[i].isna().sum()
    

    print(f'There are {missing} missing values in the {i} column')
# Out:
# There are 0 missing values in the imdb_id column
# There are 0 missing values in the budget column
# There are 0 missing values in the revenue column
# There are 1743 missing values in the certification column

# %%
tmdb_df['certification'].value_counts(dropna=False)
# Out:
# NaN        1743
# R           465
# PG-13       182
# NR           73
# PG           62
# G            25
# NC-17         6
# Unrated       1
# Name: certification, dtype: int64

# %%
tmdb_df['certification'] = tmdb_df['certification'].str.strip()

# %%
cert_replace = {'UR':'NR','Not Rated':'NR','Unrated':'NR',
                'ScreamFest Horror Film Festival':'NR','10':np.nan}
tmdb_df['certification'] = tmdb_df['certification'].replace(cert_replace)
tmdb_df['certification'].value_counts(dropna=False)
# Out:
# NaN      1743
# R         465
# PG-13     182
# NR         74
# PG         62
# G          25
# NC-17       6
# Name: certification, dtype: int64

# %%
tmdb_df = tmdb_df[['imdb_id','budget','revenue','certification']]
tmdb_df.info()
tmdb_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2557 entries, 0 to 2557
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        2557 non-null   object
#  1   budget         2557 non-null   float64
#  2   revenue        2557 non-null   float64
#  3   certification  814 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 99.9+ KB
#      imdb_id      budget     revenue certification
# 0  tt0113026  10000000.0         0.0           NaN
# 1  tt0113092         0.0         0.0           NaN
# 2  tt0116391         0.0         0.0           NaN
# 3  tt0118694    150000.0  12854953.0            PG
# 4  tt0118852         0.0         0.0             R

# %%
imdb_len = tmdb_df['imdb_id'].fillna('').map(len).max()
cert_len = tmdb_df['certification'].fillna('').map(len).max()

# %%
tmdb_schema = {
    'imdb_id': String(imdb_len+1),
    'budget': Float(),
    'revenue': Float(),
    'certification': Text(cert_len)
}

# %%
username = 'root'
password = 'root'
db_name = 'movies'
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

engine = create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/movies)

# %%
tmdb_df.to_sql('tmdb_data',engine,dtype=tmdb_schema,if_exists='replace',
              index=False)
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
q = '''Select * from title_basics limit 5;'''
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122
# 3             100
# 4             126

# %%
q = '''Select * from title_ratings limit 5;'''
pd.read_sql(q, engine)
# Out:
# Empty DataFrame
# Columns: [titleId, ordering, title, region, language, types, attributes, isOriginalTitle]
# Index: []

# %%
q = '''Select * from genres limit 5;'''
pd.read_sql(q, engine)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
q = '''Select * from tmdb_data limit 5;'''
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget     revenue certification
# 0  tt0035423  48000000.0  76019000.0         PG-13
# 1  tt0113026  10000000.0         0.0          None
# 2  tt0113092         0.0         0.0          None
# 3  tt0114447         0.0         0.0          None
# 4  tt0116391         0.0         0.0          None

# %% [markdown]
# Does the MPAA rating of a movie (G/PG/PG-13/R/NC-17) affect how much revenue the movie generates?
# Hypothesis and Choosing Test
# Hypotheses:
#
# 1. Null Hypothesis: The MPAA rating of a movie does not affect how much revenue a movie generates
#
# 2. Alternative Hypothesis: The MPAA rating of a movie does affect the amount of money a movie generates
# Choosing the Appropriate Test:
#
# The data we are looking for in the groups is numerical (revenue)
# There are more than two groups (MPAA Rating)
# *Test: One Way ANOVA*
# One Way Anova Test
# Test Assumptions:
#
# No significant outliers
# Equal variance
# Normality

# %%
g_df = tmdb_df.loc[tmdb_df['certification'] == 'G'].copy()
pg_df = tmdb_df.loc[tmdb_df['certification'] == 'PG'].copy()
pg_13_df = tmdb_df.loc[tmdb_df['certification'] == 'PG-13'].copy()
r_df = tmdb_df.loc[tmdb_df['certification'] == 'R'].copy()
nc_17_df = tmdb_df.loc[tmdb_df['certification'] == 'NC-17'].copy()
nr_df = tmdb_df.loc[tmdb_df['certification'] == 'NR'].copy()
g_df.head()
# Out:
#        imdb_id       budget      revenue certification
# 12   tt0120630   45000000.0  224834564.0             G
# 19   tt0120917  100000000.0  169327687.0             G
# 23   tt0123055          0.0          0.0             G
# 271  tt0192255   35000000.0   27965865.0             G
# 380  tt0205461   19000000.0   19748009.0             G

# %%
g_rev = g_df['revenue']
pg_rev = pg_df['revenue']
pg_13_rev = pg_13_df['revenue']
r_rev = r_df['revenue']
nc_17_rev = nc_17_df['revenue']
nr_rev = nr_df['revenue']
g_rev.head()
# Out:
# 12     224834564.0
# 19     169327687.0
# 23             0.0
# 271     27965865.0
# 380     19748009.0
# Name: revenue, dtype: float64

# %%
g_mean = g_rev.mean()
print(f'The average mean for G rated movies: ${g_mean:0.2f}')
pg_mean = pg_rev.mean()
print(f'The average mean for PG rated movies: ${pg_mean:0.2f}')
pg_13_mean = pg_13_rev.mean()
print(f'The average mean for PG-13 rated movies: ${pg_13_mean:0.2f}')
r_mean = r_rev.mean()
print(f'The average mean for R rated movies: ${r_mean:0.2f}')
nc_17_mean = nc_17_rev.mean()
print(f'The average mean for NC-17 rated movies: ${nc_17_mean:0.2f}')
nr_mean = nr_rev.mean()
print(f'The average mean for NR rated movies: ${nr_mean:0.2f}')
# Out:
# The average mean for G rated movies: $70418856.48
# The average mean for PG rated movies: $62458356.84
# The average mean for PG-13 rated movies: $71465436.49
# The average mean for R rated movies: $16178692.42
# The average mean for NC-17 rated movies: $0.00
# The average mean for NR rated movies: $2202803.57

# %%
rating_palette = {'G':'blue','PG':'green','PG-13':'yellow',
                  'R':'lightgreen','NC-17':'bisque','NR':'lightgrey'}
fig, (ax_bar) = plt.subplots(figsize=(10,6))

# Barplot
sns.barplot(data=tmdb_df, x='certification', y='revenue', ax=ax_bar, palette=rating_palette)
ax_bar.ticklabel_format(style='plain', axis='y')
fig.suptitle('Comparison of Revenue by MPAA Ratings', fontsize='xx-large');

# %%
# Create groups dictionary
# Empty dictionary
groups = {}

# For loop to iterate through dataframe to assign certifications to keys and 
# revenue to values
for i in tmdb_df['certification'].unique():
    
    # Get series for group and rename
    data = tmdb_df.loc[tmdb_df['certification'] == i, 'revenue'].copy()
    
    # Save into dictionary
    groups[i] = data
groups.keys()
# Out:
# dict_keys([nan, 'PG', 'R', 'G', 'NR', 'PG-13', 'NC-17'])

# %%
# Test normality
# Run normal test on each group
norm_results = {}

for i, data in groups.items():
    stat, p = stats.normaltest(data)
    norm_results[i] = {'n': len(data), 'p': p, 'test stat': stat}

# Convert to dataframe
norm_results_df = pd.DataFrame(norm_results).T
### checking sig with pandas 
norm_results_df['sig'] = norm_results_df['p'] < .05 
norm_results_df
# Out:
# C:\Users\dhowa\anaconda3\envs\dojo-env\lib\site-packages\scipy\stats\_stats_py.py:1343: RuntimeWarning: Mean of empty slice.
#   mean = a.mean(axis, keepdims=True)
# C:\Users\dhowa\anaconda3\envs\dojo-env\lib\site-packages\numpy\core\_methods.py:182: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
# C:\Users\dhowa\anaconda3\envs\dojo-env\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\dhowa\anaconda3\envs\dojo-env\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [37], line 6
#       3 norm_results = {}
#       5 for i, data in groups.items():
# ----> 6     stat, p = stats.normaltest(data)
#       7     norm_results[i] = {'n': len(data), 'p': p, 'test stat': stat}
#       9 # Convert to dataframe
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\scipy\stats\_stats_py.py:1868, in normaltest(a, axis, nan_policy)
#    1865     a = ma.masked_invalid(a)
#    1866     return mstats_basic.normaltest(a, axis)
# -> 1868 s, _ = skewtest(a, axis)
#    1869 k, _ = kurtosistest(a, axis)
#    1870 k2 = s*s + k*k
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\scipy\stats\_stats_py.py:1673, in skewtest(a, axis, nan_policy, alternative)
#    1671 n = a.shape[axis]
#    1672 if n < 8:
# -> 1673     raise ValueError(
#    1674         "skewtest is not valid with less than 8 samples; %i samples"
#    1675         " were given." % int(n))
#    1676 y = b2 * math.sqrt(((n + 1) * (n + 3)) / (6.0 * (n - 2)))
#    1677 beta2 = (3.0 * (n**2 + 27*n - 70) * (n+1) * (n+3) /
#    1678          ((n-2.0) * (n+5) * (n+7) * (n+9)))
#
# ValueError: skewtest is not valid with less than 8 samples; 0 samples were given.

# %%
# Testing for equal variance
stats.levene(*groups.values())
# Out:
# LeveneResult(statistic=nan, pvalue=nan)

# %%
result = stats.kruskal(*groups.values())
result
# Out:
# KruskalResult(statistic=nan, pvalue=nan)
